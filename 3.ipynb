# %% [markdown]
# ## Pandas Profiling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\ishan\anaconda3\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 2.5.0)
#   from scipy.stats import gaussian_kde

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")

# %%
df.sample(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1786             18          91                  Low                High
# 3392             20          89                 High                High
# 6488             22          87                 High                High
# 4206             23          88                 High                 Low
# 3829             23          73                  Low                High
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1786                        Yes            9               81
# 3392                        Yes            8               52
# 6488                        Yes            8               64
# 4206                        Yes            6               58
# 3829                         No            5               60
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 1786             High             Yes                  4          High
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.dropna(subset=["Teacher_Quality","Parental_Education_Level","Distance_from_Home"], inplace=True)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Distance_from_Home"].unique()
# Out:
# array(['Near', 'Moderate', 'Far'], dtype=object)

# %%
df["Parental_Education_Level"].unique()
# Out:
# array(['High School', 'College', 'Postgraduate'], dtype=object)

# %%
X = df.iloc[:, 16:18]

# %%
X
# Out:
#      Parental_Education_Level Distance_from_Home
# 0                 High School               Near
# 1                     College           Moderate
# 2                Postgraduate               Near
# 3                 High School           Moderate
# 4                     College               Near
# ...                       ...                ...
# 6602              High School               Near
# 6603              High School               Near
# 6604             Postgraduate               Near
# 6605              High School                Far
# 6606             Postgraduate               Near
#
# [6378 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, df.iloc[:, -1], test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      Parental_Education_Level Distance_from_Home
# 2356              High School           Moderate
# 4758                  College           Moderate
# 2281              High School           Moderate
# 485              Postgraduate               Near
# 4200              High School               Near
# ...                       ...                ...
# 3904             Postgraduate               Near
# 5378              High School               Near
# 5415             Postgraduate           Moderate
# 5582                  College               Near
# 894              Postgraduate                Far
#
# [5102 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(categories=[["High School", "College", "Postgraduate"], ["Near", "Moderate", "Far"]])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['High School', 'College', 'Postgraduate'],
#                            ['Near', 'Moderate', 'Far']])

# %%
oe.transform(X_train)
oe.transform(X_test)
# Out:
# array([[0., 2.],
#        [0., 0.],
#        [0., 0.],
#        ...,
#        [0., 0.],
#        [1., 0.],
#        [1., 1.]], shape=(1276, 2))
